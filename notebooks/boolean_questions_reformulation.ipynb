# %%
import numpy as np

import requests
import json

from difflib import SequenceMatcher
import re

from tqdm import tqdm

import sys
print(sys.executable)
# Out:
# /home/jupyter-simon_horvat/.conda/envs/simon_env/bin/python

# %%
from deep_translator import GoogleTranslator

API_URL = "http://localhost:11434/api/generate"
MODEL = "llama3.3:latest"

translator_de = GoogleTranslator(source="en", target="de")
translator_fr = GoogleTranslator(source="en", target="fr")

responses = []

for i, order in enumerate(tqdm(data['data'][:10], total=10, desc="Generovanie boolean otazok")):
    if len(order['paragraphs']) < 3:
        continue
    paragraph_en = order['paragraphs'][0]
    paragraph_de = order['paragraphs'][1]
    paragraph_fr = order['paragraphs'][2]
    
    context = paragraph_en['context']
    response = ask_question(context, "en", MODEL, API_URL, num_questions=10, prompt_number=3)

    responses.append(response)
    extend_response_file(response)
#     response = responses[i]
    
    json_pattern = r'\{(?:[^{}]|(?R))*\}'
    match = regex.search(json_pattern, response, re.DOTALL)

    if match:
        json_data = match.group(0)
        try:
            parsed_data = json.loads(json_data)
            
            max_id_en = max(q['id'] for q in paragraph_en['qas'])
            max_id_de = max(q['id'] for q in paragraph_de['qas'])
            max_id_fr = max(q['id'] for q in paragraph_fr['qas'])
            
            for i, qa in enumerate(parsed_data['qa']):
                answer = qa['a'].strip() if isinstance(qa['a'], str) else qa['a']
                qa_dict_en = {
                    "id": max_id_en + i + 1,
                    "question": qa['q'],
                    "lang": "en",
                    "answers": [{
                        "text": answer,
                        "answer_type": "boolean"
                    }]
                }
                qa_dict_de = {
                    "id": max_id_de + i + 1,
                    "question": translator_de.translate(qa["q"]),
                    "lang": "de",
                    "answers": [{
                        "text": answer,
                        "answer_type": "boolean"
                    }]
                }
                qa_dict_fr = {
                    "id": max_id_fr + i + 1,
                    "question": translator_fr.translate(qa["q"]),
                    "lang": "fr",
                    "answers": [{
                        "text": answer,
                        "answer_type": "boolean"
                    }]
                }
                
                paragraph_en["qas"].append(qa_dict_en)
                paragraph_en["qas"].append(qa_dict_de)
                paragraph_en["qas"].append(qa_dict_fr)
                
                paragraph_de["qas"].append(qa_dict_en)
                paragraph_de["qas"].append(qa_dict_de)
                paragraph_de["qas"].append(qa_dict_fr)
                
                paragraph_fr["qas"].append(qa_dict_en)
                paragraph_fr["qas"].append(qa_dict_de)
                paragraph_fr["qas"].append(qa_dict_fr)

        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("No JSON data found.")

# %%
def extract_json_responses(response):
    content_array = response.content.decode().split("\n")[:-1]
    content_array = [json.loads(j)["response"] for j in content_array]
    content = "".join(content_array)
    return content

def make_post_request(prompt):
    payload = {
        "model": MODEL,
        "prompt": prompt
    }
    headers = {
        "Content-Type": "application/json"
    }

    response = requests.post(API_URL, json=payload, headers=headers)

    if response.status_code != 200:
        print("Error: {}".format(response.status_code))

    return response

def is_yes_no_question(question):
    yes_no_keywords = ["is", "are", "do", "does", "did", "can", "could", "will", "would", "should", "has", "have", "had", "was"]
    return any(question.lower().startswith(keyword) for keyword in yes_no_keywords)

def validate_response(output):
    # Check if the output is a dictionary
    if not isinstance(output, dict):
        return False
    
    # Check if "id" is a string and exists in the dictionary
    if not isinstance(output.get("id"), str):
        return False
    
    # Check if "question" is a string and exists in the dictionary
    if not isinstance(output.get("question"), str):
        return False
    
    # Check if "answers" is a list
    answers = output.get("answers")
    if not isinstance(answers, list):
        return False
    
    # Check if each item in "answers" is a dictionary with the required keys
    for answer in answers:
        if not isinstance(answer, dict):
            return False
        if not set(answer.keys()).issubset({"text", "answer_type"}):
            return False
        if not isinstance(answer.get("text"), str) or not isinstance(answer.get("answer_type"), str):
            return False
    
    return True

# %%
def zly_format_pocet(data):
    zly_format = 0

    for item in data['data']:
        yes_no_paragraphs = []
        general_paragraphs = []
        for paragraph in item['paragraphs']:
            for question in paragraph['qas']:
                for answer in question['answers']:
                    answer_type = answer.get('answer_type')
                    if answer_type == "boolean" and not is_yes_no_question(question["question"]):
                        zly_format += 1

    return zly_format

def pocty_typov_odpovedi(data):
    # Overenie ci mame len otazky typu string

    """Counts the occurrences of each answer type in the dataset."""
    type_counts = {"string": 0, "number": 0, "boolean": 0}

    for item in data['data']:
        for paragraph in item['paragraphs']:
            for question in paragraph['qas']:
                for answer in question['answers']:
                    answer_type = answer.get('answer_type')
                    if answer_type in type_counts:
                        type_counts[answer_type] += 1

    return(f'Answer Type Statistics: {type_counts}')

# %%
response = '''{
       "id": "13",
       "question": "Is the pickup location located in Oklahoma City?",
       "answers": [
          {"text": "True", "answer_type": "boolean"}
       ]
    }'''

validate_response(json.loads(response))
# Out:
# True

# %%
with open("synthetic_data_200_SQuAD_placeholders_replaced.json", 'r') as file:
    data = json.load(file)
    print(len(data["data"]))
#     data["data"] = data["data"][:50]
#     print(len(data["data"]))
# Out:
# 200

# %%
pocty_typov_odpovedi(data)
# Out:
# "Answer Type Statistics: {'string': 2156, 'number': 502, 'boolean': 1264}"

# %%
zly_format_pocet(data)
# Out:
# 0

# %%
API_URL = "http://localhost:11434/api/generate"
MODEL = "mistral"

for item in tqdm(data['data'], total=len(data['data']), desc="Reformulacia otazok"):
    yes_no_paragraphs = []
    general_paragraphs = []
    for paragraph in item['paragraphs']:
        for question in paragraph['qas']:
            for answer in question['answers']:
                answer_type = answer.get('answer_type')
                if answer_type == "boolean" and not is_yes_no_question(question["question"]):
                    response = ""
                    counter = 1
#                     print(question)
#                     while not validate_response(response):
#                         if counter > 1:
#                             print("Opakovany prompt")
#                             print(f"invalid response: {response}")
                    prompt = f'''
                        Please reformulate these questions to questions that will start with question word and remain True/False questions: 
                         {question}
                        Please maintain the exact JSON format of questions, just replace former question with new formulation
                    '''
                    try:
                        response = json.loads(extract_json_responses(make_post_request(prompt)).strip())
#                           print(type(response))
                        counter += 1
                    except (json.JSONDecodeError, KeyError):
                        print(f"Error parsing response or missing 'question' key in response: {response}")

                    reformulated_question = response["question"]
                    question["question"] = reformulated_question
                            
    
    with open("synthetic_data_200_SQuAD_placeholders_replaced_reformulated.json", 'w') as file:
        json.dump(data, file, indent=4)
# Out:
# Reformulacia otazok: 100%|██████████| 200/200 [02:50<00:00,  1.17it/s]

# %%
yes = 0
no = 0

for item in data['data']:
    yes_no_paragraphs = []
    general_paragraphs = []
    for paragraph in item['paragraphs']:
        for question in paragraph['qas']:
            for answer in question['answers']:
                answer_type = answer.get('answer_type')
                if answer_type == "boolean":
                    print(question)
                    print(answer)
                    if answer["text"] == "True":
                        yes += 1
                    else:
                        no += 1
                        
print(yes, no)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load model and tokenizer
model_name = "ramsrigouthamg/t5_paraphraser"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Prepare input text with the required prefix
input_text = "Please reformulate question given as question that starts with question word: The pickup location is in Oklahoma City?"
inputs = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True)

# Generate the paraphrased output
outputs = model.generate(
    inputs,
    max_length=128,
    num_beams=5,
    early_stopping=True
)

# Decode and print the paraphrase
paraphrased_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("Paraphrased Question:", paraphrased_text)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Paraphrased Question: Please reformulate question given as question that starts with question word. The pickup location is in Oklahoma City?

# %%
# API_URL = "http://localhost:11434/api/generate"
# # MODEL = "llama3.3:latest"
# MODEL = "mistral"

# prompt = '''
#     Please reformulate these questions to questions that will start with question word and remain True/False questions: 
#     {'id': '13', 'question': 'The pickup location is in Oklahoma City', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
#     {'id': '14', 'question': 'The delivery location is in Belarus', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
#     {'id': '15', 'question': 'The pickup time is on July 6th at 13:00', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
#     {'id': '16', 'question': 'The delivery time is on July 9th at 18:00', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
#     {'id': '17', 'question': 'The cargo has a weight of 49 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
#     {'id': '18', 'question': 'The cargo has dimensions of Length - 47m, Width - 17m, Height - 35m', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
#     Please maintain the exact JSON format of questions, just replace former question with new formulation'''

# response = extract_json_responses(make_post_request(prompt)).strip()
# print(response)

API_URL = "http://localhost:11434/api/generate"
# MODEL = "llama3.3:latest"
MODEL = "mistral"

prompt = '''
    Please reformulate these questions to questions that will start with question word and remain True/False questions: 
     {'id': '17', 'question': 'The cargo has a weight of 49 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
    Please maintain the exact JSON format of questions, just replace former question with new formulation'''

response = extract_json_responses(make_post_request(prompt)).strip()
print(response)
# Out:
# {
#      "id": "17",
#      "question": "Is the weight of the cargo 49 kg?",
#      "answers": [
#        {"text": "True", "answer_type": "boolean"}
#      ]
#    }

# %%
# Overenie ci mame len otazky typu string

"""Counts the occurrences of each answer type in the dataset."""
type_counts = {"string": 0, "number": 0, "boolean": 0}

for item in general_data['data']:
    for paragraph in item['paragraphs']:
        for question in paragraph['qas']:
            for answer in question['answers']:
                answer_type = answer.get('answer_type')
                if answer_type in type_counts:
                    type_counts[answer_type] += 1
                    if answer_type == "boolean":
                        print(question)

f'Answer Type Statistics: {type_counts}'
# Out:
# {'id': '13', 'question': 'The pickup location is in Oklahoma City', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The delivery location is in Belarus', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The pickup time is on July 6th at 13:00', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The delivery time is on July 9th at 18:00', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The cargo has a weight of 49 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The cargo has dimensions of Length - 47m, Width - 17m, Height - 35m', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'A refrigerator truck (Frigo) is required for the transportation', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The route includes a stop in LG Electronics, Oklahoma City, POSTAL_CODE', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The pickup location is in Cleveland, 16306.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The packages have impressive dimensions.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'All the packages are stackable.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'A Sprinter is required for transportation.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The pickup and delivery times are ASAP.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The goods need to be delivered as soon as possible.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'The text is written in an urgent tone.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '3', 'question': 'The pickup schedule for the transportation order starts on Monday, October 19, 1997, at 22:30', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '4', 'question': 'The delivery schedule for the transportation order ends on Sunday, October 28, 1997, at 02:00', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '5', 'question': 'The goods weighing 211 kg have dimensions of Length: 79cm, Width: 56cm, and Height: 82cm', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '6', 'question': 'The goods will be transported in three packages with the following dimensions: Package Dimensions are Length: 74cm, Width: 96cm, Height: 48cm, and Weight: 26kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '7', 'question': 'The length of the second package is 57cm', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '8', 'question': 'The weight of the third package is 54kg', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'The transportation order requires a vehicle with curtain sides and a tilt function (a big lorry)', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The transportation order is for a single package', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The shipment will be picked up from LG Electronics on Pine 1955 in Chicago, 76342, Comoros', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The shipment weighs 29 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'Sideboards are required for the transportation', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The delivery will be made to RWE on Spruce 1989 in El Paso, 57054, Madagascar', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'The delivery will be made between 13:00 and 16:00 on February 19th', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '22', 'question': 'The transportation order is for a Van', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The shipments have a total weight of more than 500 kg', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'The first pickup point is located at Merck', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The second delivery point is located at JX Holdings', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'All packages require a tail lift for securement', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The shipments have different dimensions and weights', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The first shipment weighs 392 kg and has two packages', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The second shipment weighs 196 kg and has one package', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '8', 'question': 'What is the weight of item 1?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'Must the goods be delivered to Telstra located at 29983 between 19:15 on January 14th and 04:00 on January 22nd?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'Must the delivery be made between 9:00 PM and 10:00 PM on April 14th, 2001?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '1', 'question': 'The text describes a new technology that can convert carbon dioxide into oxygen.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '2', 'question': 'The technology uses a special membrane to separate oxygen and nitrogen from the air.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '3', 'question': 'The new technology is based on an ancient concept that has been around for thousands of years.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '4', 'question': 'The technology has the potential to revolutionize the way we generate energy and reduce our carbon footprint.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '5', 'question': 'The technology is still in the experimental phase and has not yet been tested on a large scale.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '6', 'question': 'The technology could have significant implications for industries such as transportation and energy production.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '7', 'question': 'The technology is expected to be commercially available within the next few years.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The shipment includes two packages', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'The total weight of the shipment is 168 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The dimensions of each package are 26cm x 88cm x 44cm', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The shipment requires ADR (dangerous goods)', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The pickup location is in Bhutan', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The delivery location is in Cabo Verde', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The shipment must be delivered between 19:45 and 21:00 on December 15th, 2025', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The forwarding team should use a Van with an experienced driver for this shipment', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The transportation order is for Cisco Systems', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'The pickup location is in the United States', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '22', 'question': 'The delivery location is also in the United States', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '23', 'question': 'The goods are dangerous and require ADR requirements to be met', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '24', 'question': 'The transportation order includes a special request for a Sprinter vehicle', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '25', 'question': 'The weight of the goods is over 173 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '26', 'question': 'The dimensions of the goods include length, width, and height', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '27', 'question': 'The transportation order includes a delivery time of April 2nd, 2003 at 12:45 PM', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The pickup location is on Cedar 648 in 18656', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'There are two items being transported, each with different dimensions', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The estimated delivery time is on October 3, 1997, at around 10:15 a.m.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'A Big lorry with sideboards is required for transportation', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'The transportation process will take approximately two days', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '22', 'question': 'LOADING AND UNLOADING MUST BE AVAILABLE DURING THE DESIGNATED PICKUP AND DELIVERY TIMES', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'Must the items be transported separately?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The pickup time is scheduled for April 9th', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The goods are being picked up from Nippon Yusen in San Antonio, 78516, Czech Republic', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The goods are scheduled to be delivered between April 20th and April 28th', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The goods weigh a total of 272 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The goods are stackable and require a tilt (curtain sided van) for easy loading and unloading', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The transportation order is for USAA', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The delivery time is scheduled at 12:15 PM', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'What is the weight of Item 1?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'What is the height of Item 2?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'What is the width of Item 3?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'What is the weight of Package 1?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'What is the height of Package 2?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'What is the total weight of the shipment?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The pickup location is in the 50020 postal code', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The goods have a length of 22 meters and a width of 94 meters', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The goods weigh 21 kilograms in total', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The delivery location is in the 33102 postal code', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The Sprinter van is required for this task', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The delivery will be made on August 28th at 3 pm', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'All necessary equipment and personnel are included in the request', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'What is the weight of item 1?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'What is the height of item 2?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '4', 'question': 'The shipment includes small packages', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '5', 'question': 'The items require special vehicle requests', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '6', 'question': 'The delivery date is September 24th', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '7', 'question': 'The packages are not stackable', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '8', 'question': 'The weight of the items is around 218 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'The delivery includes several smaller packages', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The dimensions of the larger packages are 75m x 67m x 71m', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'Must a Van with round-trip travel be used for delivery?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The pick-up location is at Freddie Mac on 93194 and Broadway 1893.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'The pick-up time frame is between April 17, 2034, 2:30 AM, and April 19, 2034, 8:00 AM.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The goods are 416 kg in weight.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The goods have a volume of 104 kg.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The goods are stackable.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': "The delivery location is at Lowe's on 41209 and Ash 647.", 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The delivery time frame is between April 21, 2034, 3:15 AM, and April 28, 2034, 3:30 AM.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The required vehicle for this transportation order is a Van with a tilt feature (curtain sided van).', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The shipment consists of four packages', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'The goods are ADR-required dangerous goods', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The vehicle needs to accommodate the shipment safely', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The driver needs to have the necessary certifications and training to handle these materials', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The shipment is stackable', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The lorry needs to be equipped with proper stacking rails to prevent any damage or shifting during transit', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The pickup location is in Memphis, 05986', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The delivery location is in Mesa, 24150', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'The pickup location is Lloyds Banking Group.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The shipment consists of two items only.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'Item 1 has a length of 75 cm.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'Item 2 has a length of 63 cm.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The weight of Item 1 is 58 kg.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The weight of Item 2 is 26 kg.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The transportation requires a big lorry.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The round trip request is included in the transportation requirements.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The pickup location is in Italy', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The delivery location is in Bahrain', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The items weigh a total of 233 kg', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The items have dimensions that vary', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'We require a large vehicle, specifically an LKW', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The delivery is scheduled for March 2nd, 1997 at 00:00:00', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'We have provided specific requirements for the vehicle and drivers', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'The pickup location is in Croatia?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The delivery location is in Djibouti?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'The packages have unique dimensions?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The lorry with curtain-sided sides is required for both pickup and delivery?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The pickup time is between 2:30 PM and 10:45 AM?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The delivery time is by 8:15 PM on February 12th?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The packages need to be delivered to Pinnacle Financial Partners in 43271?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '1', 'question': 'The article discusses the potential benefits of using AI in education.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '2', 'question': 'The author suggests that AI can personalize learning for individual students.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '3', 'question': 'The article notes that AI can help teachers by automating administrative tasks.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '4', 'question': 'The author argues that AI will eventually replace human teachers altogether.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '5', 'question': 'The article suggests that AI can help students develop critical thinking skills.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '6', 'question': 'The author believes that AI will never be able to replicate the creativity and originality of human teachers.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '7', 'question': 'The article notes that AI can help students learn at their own pace.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '8', 'question': 'The author predicts that AI will revolutionize the education industry in the near future.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'What is the delivery location Dai-ichi Mutual Life Insurance in Lincoln?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'What is the weight of Good #1?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The pickup location is in Riverside.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The delivery location is in Chesapeake.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'There are four packages being transported.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The goods include dangerous goods (ADR).', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The pickup time is on July 7th at 20:30.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The delivery time is on July 12th at 23:30.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The small lorry is required for transportation.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'The postal code for the pickup location is 12697.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'What is the weight of the goods?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '22', 'question': 'The transport order is for a single package.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '23', 'question': 'The packages need to be transported using an LKW because of their size and weight.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '24', 'question': 'The first parcel is the largest and measures 13 meters long, 36 meters wide, and 29 meters high.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '25', 'question': 'The second parcel weighs about 74 kg and measures 95 meters long, 99 meters wide, and 24 meters tall.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '26', 'question': 'The third parcel is the smallest and weighs about 18 kg.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '27', 'question': 'All three packages need to be transported using an LKW because of their size and weight.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '28', 'question': 'The delivery location is in Tulsa by December 15th, 2034, at 2:00 AM.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The transportation order is for a shipment of goods from Robert Half International Inc. in Memphis, 92140', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The transportation order requires a Small lorry with a tilt (curtain sided van)', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The goods include two items with different dimensions and weights', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The delivery location is Merck in Boise, 72028', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The goods are not stackable', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The transportation order is for a single shipment on 2004-05-02 between 1:00 and 12:45', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '21', 'question': 'The goods will be delivered on 2004-05-04 between 17:45 and 20:45', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '22', 'question': 'The transportation order includes a request for a Small lorry with a tilt (curtain sided van)', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '11', 'question': 'The pickup time is between 2018-02-17 02:45:00 and 2018-02-17 09:45:00.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The delivery time is between 2018-02-17 18:00:00 and 2018-02-27 15:00:00.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The goods weigh a total of 175 kg.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'All dimensions are stackable.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The shipment requires a Van for transportation.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The pickup and delivery locations are in the same city.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'There are four different dimensions of goods to be delivered.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': "The transportation order is for a company called Lowe's.", 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The pickup location is in Glendale, 75665.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The delivery location is in Oklahoma City, 25911.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The goods include a length of something that is 62m long, 19m wide, and 55m high.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The tallest item is taller than the truck can carry, so a special vehicle with a height of at least 66m is required to accommodate it.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The shortest item is only 12m long but 70m wide.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'All items weigh less than 80kg each, so the truck must have a weight capacity of at least 222kg to accommodate all of them.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The pickup and delivery locations are in the same country?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The first item has a length of 56 cm and a weight of 73 kg?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The required vehicle is a Sprinter with a tilt feature?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The second item has a length of 44 cm and a weight of 74 kg?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The delivery location is in the same city as the pickup location?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '19', 'question': 'The transportation order requires ASAP pickup and delivery?', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '20', 'question': 'The weight of the first item is greater than the weight of the second item?', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '4', 'question': 'The pick-up time window is between 22:00:00 on Jan 3rd, 2042, and 15:15:00 on Jan 4th, 2042.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '5', 'question': 'The delivery time window is between 16:00:00 on January 5th, 2042, and 22:15:00 on January 10th, 2042.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '6', 'question': 'The cargo consists of two goods that cannot be stacked.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '7', 'question': 'A double-driver vehicle (LKW) is required for the transportation.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '8', 'question': 'The goods have different dimensions and weights.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'The pick-up and delivery information are provided in the text.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The transportation order is for a shipment of two goods that cannot be stacked, and requires a double-driver vehicle (LKW).', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '4', 'question': 'The pickup time is before 7:00 AM on March 14th, 1996', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '5', 'question': 'The delivery time is after 3:30 PM on March 15th, 1996', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '6', 'question': 'The pickup location is in Henderson with postal code 31642', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '7', 'question': 'The delivery location is in Garland with postal code 07981', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '8', 'question': 'A frigo truck (refrigerator) is required for this delivery', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '9', 'question': 'The goods weigh 12 kg and measure 98m x 96m x 56m', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '10', 'question': 'The pickup and delivery times are specific and cannot be changed', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '12', 'question': 'The pickup location is in Armenia.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '13', 'question': 'The delivery location is in Haiti.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '14', 'question': 'The goods are too heavy to be transported in a standard Sprinter.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '15', 'question': 'The double driver is required for the job.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '16', 'question': 'The pickup time is only available on December 28th.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# {'id': '17', 'question': 'The delivery time is only available from January 3rd to January 13th.', 'answers': [{'text': 'True', 'answer_type': 'boolean'}]}
# {'id': '18', 'question': 'The Sprinter used for transportation will have a special dimension to accommodate the long and heavy goods.', 'answers': [{'text': 'False', 'answer_type': 'boolean'}]}
# "Answer Type Statistics: {'string': 2134, 'number': 502, 'boolean': 213}"
